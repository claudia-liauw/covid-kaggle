# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# # Clean data

# %% [markdown]
# ## Replace special characters and convert to snake case

# %%
df = pd.read_csv('../data/Data.csv')
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace('\(%\)', 'percent')
df.columns = df.columns.str.replace('/', ' per ')
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#          entity continent  latitude  longitude  average_temperature_per_year  \
# 0       Albania    Europe     41.15      20.17                            14
# 1       Albania    Europe     41.15      20.17                            14
# 2       Albania    Europe     41.15      20.17                            14
# 3       Albania    Europe     41.15      20.17                            14
# 4       Albania    Europe     41.15      20.17                            14
# ...         ...       ...       ...        ...                           ...
# 38467  Zimbabwe    Africa    -19.02      29.15                            20
# 38468  Zimbabwe    Africa    -19.02      29.15                            20
# 38469  Zimbabwe    Africa    -19.02      29.15                            20
# 38470  Zimbabwe    Africa    -19.02      29.15                            20
# 38471  Zimbabwe    Africa    -19.02      29.15                            20
#
# ...

# %% [markdown]
# ## Check data types and completeness of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38472 entries, 0 to 38471
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   entity                               38472 non-null  object
#  1   continent                            38472 non-null  object
#  2   latitude                             38472 non-null  float64
#  3   longitude                            38472 non-null  float64
#  4   average_temperature_per_year         38472 non-null  int64
#  5   hospital_beds_per_1000_people        38472 non-null  float64
#  6   medical_doctors_per_1000_people      38472 non-null  float64
#  7   gdp_per_capita                       38472 non-null  float64
#  8   population                           38472 non-null  int64
#  9   median_age                           38472 non-null  int64
#  10  population_aged_65_and_over_percent  38472 non-null  int64
# ...

# %% [markdown]
# Without further information, we can leave it.

# %% [markdown]
# # Derived features

# %%
df['cases_per_capita'] = df.cases / df.population
df['deaths_per_capita'] = df.deaths / df.population
